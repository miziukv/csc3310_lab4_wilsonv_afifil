# %% [markdown]
# # CSC 3310
# ## Lab 04: Selection Problem
# ### Vlad Wilson and Leena Afifi
# #### Dr. Sebastion Berisha

# %% [markdown]
# # Test cases

# %%
def run_tests():
    test_cases = [
        # (array, k, expected)
        ([5, 1, 6, 7, 3, 4, 8], 3, 4),        
        ([9, 8, 7, 6, 5, 4, 3, 2, 1], 1, 1),  
        ([9, 8, 7, 6, 5, 4, 3, 2, 1], 9, 9),  
        ([10, 4, 5, 8, 6, 11, 26], 5, 10),    
        ([3, 3, 3, 3, 3], 2, 3),              
        ([1, 2], 2, 2),                       
        ([7], 1, 7),                          
    ]

    print("=== Quickselect Test Results ===")
    passed = 0

    for i, (arr, k, expected) in enumerate(test_cases, 1):
        result = quickselect(arr.copy(), k)
        print(f"Test {i}: Array={arr}, k={k}")
        print(f"Expected: {expected}, Got: {result}")
        if result == expected:
            print("Passed\n")
            passed += 1
        else:
            print("Failed\n")
    
    print(f"Summary: {passed}/{len(test_cases)} tests passed.")
    return passed == len(test_cases)

if __name__ == "__main__":
    run_tests()
# Out:
# === Quickselect Test Results ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 30
#      27     return passed == len(test_cases)
#      29 if __name__ == "__main__":
# ---> 30     run_tests()
#
# Cell In[2], line 17, in run_tests()
#      14 passed = 0
#      16 for i, (arr, k, expected) in enumerate(test_cases, 1):
# ---> 17     result = quickselect(arr.copy(), k)
#      18     print(f"Test {i}: Array={arr}, k={k}")
#      19     print(f"Expected: {expected}, Got: {result}")
#
# NameError: name 'quickselect' is not defined
